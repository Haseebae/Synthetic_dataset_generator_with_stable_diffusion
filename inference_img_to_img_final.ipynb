# %%
import torch
from PIL import Image
from io import BytesIO

from diffusers import StableDiffusionImg2ImgPipeline
from diffusers.utils import load_image

device = "mps"
model_id_or_path = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(model_id_or_path, torch_dtype=torch.float16)
pipe = pipe.to(device)

img = load_image("german_road.jpg")
init_image = img.resize((768, 512))

prompt = "forest everywhere"

image = pipe(prompt=prompt, image=init_image, strength=0.75, guidance_scale=7.5).images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/37 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
prompt = "indian city"

image = pipe(prompt=prompt, image=init_image, strength=0.75, guidance_scale=7.5).images[0]
image
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
# !pip install jinaai
# Out:
# Collecting jinaai
#   Downloading jinaai-0.2.9-py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in /Users/haseeb/miniconda3/envs/stable_diffusion/lib/python3.9/site-packages (from jinaai) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haseeb/miniconda3/envs/stable_diffusion/lib/python3.9/site-packages (from requests->jinaai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/haseeb/miniconda3/envs/stable_diffusion/lib/python3.9/site-packages (from requests->jinaai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/haseeb/miniconda3/envs/stable_diffusion/lib/python3.9/site-packages (from requests->jinaai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/haseeb/miniconda3/envs/stable_diffusion/lib/python3.9/site-packages (from requests->jinaai) (2022.12.7)
# Installing collected packages: jinaai
# Successfully installed jinaai-0.2.9
